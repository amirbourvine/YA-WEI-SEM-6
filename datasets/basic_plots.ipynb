# %%
from basic_plots import *
# %matplotlib inline

# %%
df = read_dataset("paviaU.csv")
X = np.array(df)

df_gt = read_dataset("paviaU_gt.csv")
y = np.array(df_gt)

zero_labeled = np.argwhere(y.ravel() == 0)
zero_labeled = [idx for [idx] in zero_labeled]

print_basic_statistics(df, y)
# Out:
# (610, 340)
# Shape is:  (207400, 103)
#    class_name  samples
# 0           1     6631
# 1           2    18649
# 2           3     2099
# 3           4     3064
# 4           5     1345
# 5           6     5029
# 6           7     1330
# 7           8     3682
# 8           9      947
# class_name       45
# samples       42776
# dtype: int64

# %%
plot_spectral_band(df)

# %%
plot_gt(df_gt)

# %%
plot_composite(df)
