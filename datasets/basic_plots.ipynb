# %%
from basic_plots import *
# %matplotlib inline

# %%
df = read_dataset("KSC.csv")
X = np.array(df)

df_gt = read_dataset("KSC_gt.csv")
y = np.array(df_gt)

zero_labeled = np.argwhere(y.ravel() == 0)
zero_labeled = [idx for [idx] in zero_labeled]

print_basic_statistics(df, y)
# Out:
# Shape is:  (314368, 176)
#     class_name  samples
# 0            1      761
# 1            2      243
# 2            3      256
# 3            4      252
# 4            5      161
# 5            6      229
# 6            7      105
# 7            8      431
# 8            9      520
# 9           10      404
# 10          11      419
# 11          12      503
# 12          13      927
# class_name      91
# samples       5211
# dtype: int64

# %%
plot_spectral_band(df)

# %%
plot_gt(df_gt)

# %%
plot_composite(df)
